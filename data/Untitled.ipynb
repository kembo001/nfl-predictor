# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# Reload the updated 2000-2020 data
df_2000_2020_new = pd.read_csv('csv/nfl_playoff_teams_2000_2020_new.csv')

# Standardize LA to LAR (the R script uses LA for Rams)
df_2000_2020_new['team'] = df_2000_2020_new['team'].replace({'LA': 'LAR'})

df_2000_2020_new['superbowl_win'] = df_2000_2020_new['superbowl_win'].fillna('No')

# %%
df_2000_2020_new
# Out:
#     team  pass_rush_rating  sack_rate  pressure_rate  pass_block_rating  \
# 0    BAL          5.200000   0.057377       0.106557          94.631353
# 1    DEN          6.254767   0.064801       0.120766          96.524064
# 2    IND          5.612999   0.066561       0.120444          97.389413
# 3    MIA          5.840568   0.068740       0.121113          95.538721
# 4    MIN          4.335048   0.045190       0.086006          95.064541
# ..   ...               ...        ...            ...                ...
# 235  PIT         14.539830   0.088050       0.295597          93.792072
# 236  SEA         10.770328   0.058974       0.193590          87.519026
# 237   TB         12.274096   0.066574       0.226075          92.360581
# 238  TEN          6.534508   0.026912       0.126062          91.810669
# 239  WAS         10.878011   0.074132       0.220820          88.182498
#
#      sacks_allowed_rate  protection_rate          primary_qb           coach  \
# ...
